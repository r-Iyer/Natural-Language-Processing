# %%
import re

# %%
def generate_ngrams(s, n):
    s = s.lower()
    s = re.sub(r'[^a-zA-Z0-9\s]', ' ', s)
    tokens = [token for token in s.split(" ") if token != ""]
    ngrams = zip(*[tokens[i:] for i in range(n)])
    return [" ".join(ngram) for ngram in ngrams]

# %%
s = "Write a program to compute unsmoothed unigrams, bigrams and Trigrams for a sequence of words. Generalize the "\
"programs for n-grams. Create a corpus by collecting 50 web news, Create a list of frequency of words and then build a"\
"Unigram, bigram and trigram language models, respectively. Use at least three sentences as input to test your "\
"language models with any two smoothing techniques. Also, make some performance analysis to explain which model and"\
"smoothing method is better."

# %%
ngram = generate_ngrams(s,3)

# %%
print(ngram)
# Out:
# ['write a program', 'a program to', 'program to compute', 'to compute unsmoothed', 'compute unsmoothed unigrams', 'unsmoothed unigrams bigrams', 'unigrams bigrams and', 'bigrams and trigrams', 'and trigrams for', 'trigrams for a', 'for a sequence', 'a sequence of', 'sequence of words', 'of words generalize', 'words generalize the', 'generalize the programs', 'the programs for', 'programs for n', 'for n grams', 'n grams create', 'grams create a', 'create a corpus', 'a corpus by', 'corpus by collecting', 'by collecting 50', 'collecting 50 web', '50 web news', 'web news create', 'news create a', 'create a list', 'a list of', 'list of frequency', 'of frequency of', 'frequency of words', 'of words and', 'words and then', 'and then build', 'then build aunigram', 'build aunigram bigram', 'aunigram bigram and', 'bigram and trigram', 'and trigram language', 'trigram language models', 'language models respectively', 'models respectively use', 'respectively use at', 'use at least', 'at least three', 'least three sentences', 'three sentences as', 'sentences as input', 'as input to', 'input to test', 'to test your', 'test your language', 'your language models', 'language models with', 'models with any', 'with any two', 'any two smoothing', 'two smoothing techniques', 'smoothing techniques also', 'techniques also make', 'also make some', 'make some performance', 'some performance analysis', 'performance analysis to', 'analysis to explain', 'to explain which', 'explain which model', 'which model andsmoothing', 'model andsmoothing method', 'andsmoothing method is', 'method is better']

# %%
'''
import nltk
from nltk.corpus import reuters
from nltk import bigrams, trigrams
from collections import Counter, defaultdict

# Create a placeholder for model
model = defaultdict(lambda: defaultdict(lambda: 0))

# Count frequency of co-occurance  
for sentence in reuters.sents():
    for w1, w2, w3 in trigrams(sentence, pad_right=True, pad_left=True):
        model[(w1, w2)][w3] += 1
 
# Let's transform the counts to probabilities
for w1_w2 in model:
    total_count = float(sum(model[w1_w2].values()))
    for w3 in model[w1_w2]:
        model[w1_w2][w3] /= total_count
'''
# Out:
# "\nimport nltk\nfrom nltk.corpus import reuters\nfrom nltk import bigrams, trigrams\nfrom collections import Counter, defaultdict\n\n# Create a placeholder for model\nmodel = defaultdict(lambda: defaultdict(lambda: 0))\n\n# Count frequency of co-occurance  \nfor sentence in reuters.sents():\n    for w1, w2, w3 in trigrams(sentence, pad_right=True, pad_left=True):\n        model[(w1, w2)][w3] += 1\n \n# Let's transform the counts to probabilities\nfor w1_w2 in model:\n    total_count = float(sum(model[w1_w2].values()))\n    for w3 in model[w1_w2]:\n        model[w1_w2][w3] /= total_count\n"

# %%
#model['today','the']

# %%
from nltk.corpus import reuters
from collections import Counter, defaultdict
model = defaultdict(lambda: defaultdict(lambda: 0))
snew = ""
for string in reuters.sents():
    snew += " ".join(string)

ngram = generate_ngrams(snew,3)

# %%
for i in range(len(ngram)):
    [w1, w2, w3] = ngram[i].split()
    model[(w1, w2)][w3] += 1

for w1_w2 in model:
    total_count = float(sum(model[w1_w2].values()))
    for w3 in model[w1_w2]:
        model[w1_w2][w3] = round((model[w1_w2][w3] / total_count),2)

# %%
dict(model['today','the'])
# Out:
# {'0': 0.01,
#  'agriculture': 0.01,
#  'auditors': 0.01,
#  'average': 0.01,
#  'bank': 0.06,
#  'benchmark': 0.01,
#  'buena': 0.01,
#  'bulk': 0.01,
#  'canadian': 0.01,
#  'central': 0.05,
#  'china': 0.01,
#  'commerzbank': 0.01,
#  'commission': 0.01,
#  'company': 0.16,
#  'court': 0.01,
#  'csce': 0.02,
#  'dealers': 0.01,
#  'decrease': 0.03,
#  'economic': 0.01,
#  'emirate': 0.01,
#  'energy': 0.01,
#  'european': 0.01,
#  'exchange': 0.01,
#  'fed': 0.01,
#  'federal': 0.01,
#  'focus': 0.01,
#  'government': 0.01,
#  'higher': 0.01,
#  'house': 0.01,
#  'increase': 0.1,
#  'iranian': 0.01,
#  'italian': 0.01,
#  'last': 0.01,
#  'mine': 0.01,
#  'move': 0.02,
#  'new': 0.03,
#  'newspaper': 0.01,
#  'office': 0.01,
#  'official': 0.01,
#  'officials': 0.01,
#  'options': 0.01,
#  'overseas': 0.01,
#  'pilots': 0.01,
#  'planes': 0.01,
#  'plant': 0.01,
#  'pound': 0.01,
#  'price': 0.02,
#  'public': 0.01,
#  'redstone': 0.01,
#  'sale': 0.01,
#  'same': 0.01,
#  'seamen': 0.01,
#  'storm': 0.01,
#  'supreme': 0.01,
#  'tariff': 0.01,
#  'tax': 0.01,
#  'third': 0.01,
#  'time': 0.01,
#  'trade': 0.01,
#  'traders': 0.01,
#  'transaction': 0.01,
#  'treasury': 0.01,
#  'turkish': 0.01,
#  'u': 0.01,
#  'usda': 0.01,
#  'world': 0.01}

# %%
import random

text = ["today", "the"]
sentence_finished = False
 
while not sentence_finished:
    r = random.random()
    accumulator = .0

    for word in model[tuple(text[-2:])].keys():
        accumulator += model[tuple(text[-2:])][word]
        if accumulator >= r:
            text.append(word)
            break

    if len(text) >= 500:
        sentence_finished = True

print(' '.join([t for t in text if t]))
# Out:
# today the company said the offer and advise on the toronto globe and mail report when queried scott did not affect 1987 results do not exceed their quotas sparked moves to strengthen the present situation damages the interests involved he said the spokesman declined to specify at what is sees as japan did not disclose check assay results from its operating subsidiaries texaco capital n z futures volumes traded in the prior year 1986 current assets at year end 1986 shr and gain 3 200 billion yen funds would also back a commission commitment to public ownership in the system eyskens said liberalisation of capital and surplus requirements by five pct to 48 3 107 7 mln avg shrs 11 6 pct higher by the market will expand by three u s agriculture department projected china s 1986 income which was partly offset higher oilseed output is expected to total between 2 90 mln dlrs and is subject to approval by sharehoilders of both companies the bank of france said m 1 plus daily interest chequable and non members he said he expects opec to raise its bid for control the group of creditor banks worldwide agreed last month u s oil demand growth let alone an increase in the market is showing signs of renewed inflationvolcker says fed policy said robert ortner undersecretary of state controlled creditanstalt rose eight to 108 mln dlrs in nine mths shr 1 22 billion loans 6 95 pct compared with 7 9 mln vs 41 5 cts a share to restructure bojangles excluding bojangles the group of banks 76 mln cash would cover u s banks prime rates would normally be for companies that have been falling steadily since the beginning of this year and has four tire manufacturing plant targeted for sale in other areas usx said total opec production curbs have pushed miti to try to diversify and then rise to about 1 000 501 sanivan treasury shares to nim will be a sharp fall in week u s bank rate 7 20 dlrs neale goldston morris said drought in sabah the country s political leaders of the u s corn likely first there are snags in the prior year results its fiscal 1988 in des moines lt pdm gets qualified audit scott instruments corp a maker of low returns on their ability to buy an additional concession of land and securities dealers full participation by an additional 200 000 bpd opec natural gas output but not halt such attempts industry analysts said the dividend to 33 francs vs 110 9 mln vs 23 0 22 0 mln dlrs for continuing the subcommittee had not given u s soybean sales of the economy shrank 1 4 billion dlrs is traded every day our expansion schedule is called will change its citrus estimate program for rural uplift education and marketing segment showed a two year put option exercisable for one split boston bancorp lt arbc o 3rd qtr net qtr ends jan

# %%
model_bi = defaultdict(lambda : defaultdict(lambda : 0))
ngram_bi = generate_ngrams(snew,2)
model_mono = defaultdict(lambda : 0)
ngram_mono = generate_ngrams(snew,1)

# %%
for i in range(len(ngram_bi)):
    [w1, w2] = ngram_bi[i].split()
    model_bi[w1][w2] += 1

for w1 in model_bi:
    total_count = float(sum(model_bi[w1].values()))
    for w2 in model_bi[w1]:
        model_bi[w1][w2] = round((model_bi[w1][w2] / total_count),2)

# %%
dict(model_bi['francs'])
# Out:
# {'1': 0.0,
#  '16': 0.0,
#  '24': 0.0,
#  '3': 0.0,
#  '32': 0.0,
#  '396': 0.0,
#  '65': 0.0,
#  'a': 0.01,
#  'after': 0.02,
#  'against': 0.04,
#  'also': 0.0,
#  'an': 0.0,
#  'and': 0.02,
#  'as': 0.0,
#  'at': 0.02,
#  'below': 0.0,
#  'but': 0.0,
#  'by': 0.01,
#  'carries': 0.0,
#  'cash': 0.0,
#  'chief': 0.0,
#  'company': 0.0,
#  'compared': 0.01,
#  'conditions': 0.0,
#  'could': 0.0,
#  'de': 0.0,
#  'dividend': 0.0,
#  'doubling': 0.0,
#  'due': 0.0,
#  'during': 0.01,
#  'each': 0.01,
#  'earlier': 0.0,
#  'end': 0.0,
#  'entitled': 0.0,
#  'fob': 0.0,
#  'foote': 0.0,
#  'for': 0.01,
#  'french': 0.01,
#  'from': 0.09,
#  'geronimus': 0.0,
#  'had': 0.0,
#  'he': 0.0,
#  'in': 0.07,
#  'including': 0.0,
#  'instead': 0.0,
#  'into': 0.0,
#  'it': 0.0,
#  'jacobs': 0.0,
#  'jan': 0.0,
#  'january': 0.0,
#  'japan': 0.0,
#  'last': 0.02,
#  'loss': 0.01,
#  'lt': 0.0,
#  'making': 0.0,
#  'martens': 0.0,
#  'nestle': 0.0,
#  'new': 0.0,
#  'no': 0.0,
#  'nominal': 0.01,
#  'note': 0.0,
#  'notes': 0.0,
#  'of': 0.03,
#  'on': 0.02,
#  'operating': 0.0,
#  'or': 0.0,
#  'over': 0.01,
#  'pancontinental': 0.0,
#  'per': 0.06,
#  'pittston': 0.0,
#  'president': 0.0,
#  'raising': 0.0,
#  'reported': 0.0,
#  'reserves': 0.0,
#  'resulting': 0.0,
#  'revised': 0.0,
#  'seasonally': 0.0,
#  'sight': 0.01,
#  'sl': 0.0,
#  'societe': 0.0,
#  'solv': 0.0,
#  'somewhat': 0.0,
#  'south': 0.0,
#  'subtracted': 0.0,
#  'supplementary': 0.0,
#  'switzerland': 0.0,
#  'tax': 0.0,
#  'the': 0.03,
#  'then': 0.0,
#  'they': 0.0,
#  'this': 0.0,
#  'through': 0.0,
#  'to': 0.07,
#  'u': 0.01,
#  'unadjusted': 0.0,
#  'unchanged': 0.0,
#  'under': 0.0,
#  'up': 0.0,
#  'via': 0.0,
#  'vs': 0.15,
#  'was': 0.0,
#  'which': 0.0,
#  'while': 0.0,
#  'will': 0.0,
#  'with': 0.01,
#  'without': 0.0,
#  'worth': 0.01,
#  'would': 0.0,
#  'yesterday': 0.0}

# %%
model_mono = defaultdict(lambda : 0)
for i in range(len(ngram_mono)):
    w1 = ngram_mono[i]
    model_mono[w1] += 1

total_count = float(sum(model_mono.values()))
for w1 in model_mono:
    model_mono[w1] = model_mono[w1] / total_count

# %%
lambda_1 = 0.45
lambda_2 = 0.35
lambda_3 = 0.20

lambda_1 * dict(model[('asian','exporters')])['fear'] + lambda_2 * dict(model_bi['asian'])['exporters'] + lambda_3 * dict(model_mono)['asian']
# Out:
# 0.45700882280083205

# %%
dict(model['the','impact'])['of']*dict(model['impact','of'])['brazil']
# Out:
# 0.0058

# %%
dict(model)
# Out:
# {('asian',
#   'exporters'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'fear': 1.0}),
#  ('exporters',
#   'fear'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'china': 0.5,
#               'damage': 0.5}),
#  ('fear',
#   'damage'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'from': 1.0}),
#  ('damage',
#   'from'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'frigid': 0.12,
#               'last': 0.12,
#               'local': 0.12,
#               'pod': 0.12,
#               'repeated': 0.12,
#               'spill': 0.12,
#               'the': 0.12,
#               'u': 0.12}),
#  ('from', 'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'k': 0.04, 's': 0.96}),
#  ('u', 's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'japan': 0.01,
#               'and': 0.04,
#               'move': 0.0,
#               'has': 0.01,
#               'said': 0.0,
#               'threat': 0.0,
#               'the': 0.01,
#               'products': 0.0,
#               'retaliation': 0.0,
#               'up': 0.0,
#               'in': 0.0,
#               'pressure': 0.0,
#               'last': 0.0,
#               'exports': 0.01,
#               'japanese': 0.0,
#               'trade': 0.04,
#               'department': 0.01,
#               'dlrs': 0.03,
#               'securities': 0.0,
#               'regulations': 0.0,
#               'glass': 0.0,
#               'commercial': 0.0,
#               'demands': 0.0,
#               'officials': 0.02,
#               'farm': 0.0,
#               'would': 0.01,
#               'to': 0.01,
#               'insists': 0.0,
#               'he': 0.0,
#               'agriculture': 0.05,
#               'suppliers': 0.0,
#               'beef': 0.0,
#               'market': 0.01,
#               'corn': 0.02,
#               'will': 0.0,
#               'feedgrain': 0.0,
#               'position': 0.0,
#               'agricultural': 0.0,
#               'wants': 0.0,
#               'which': 0.0,
#               'limit': 0.0,
#               'based': 0.0,
#               'currency': 0.01,
#               'sanctions': 0.0,
#               'official': 0.0,
#               'not': 0.0,
#               'hopes': 0.0,
#               'investors': 0.0,
#               'dollar': 0.02,
#               'unit': 0.0,
#               'where': 0.0,
#               'soybean': 0.01,
#               'charges': 0.0,
#               'decision': 0.0,
#               'chip': 0.0,
#               'concern': 0.0,
#               'complaint': 0.0,
#               'banking': 0.0,
#               'treasury': 0.02,
#               'petrochemical': 0.0,
#               'chemical': 0.0,
#               'economy': 0.01,
#               'dlr': 0.01,
#               'textile': 0.0,
#               'investor': 0.0,
#               'defense': 0.0,
#               'government': 0.02,
#               'no': 0.0,
#               'a': 0.0,
#               'parent': 0.0,
#               'acquisition': 0.0,
#               'tariffs': 0.0,
#               'semiconductor': 0.0,
#               'firms': 0.01,
#               'purchase': 0.0,
#               'medical': 0.0,
#               'subsidiary': 0.0,
#               'loan': 0.0,
#               'lawmakers': 0.0,
#               'dairy': 0.0,
#               'interest': 0.0,
#               'engineering': 0.0,
#               'reserves': 0.0,
#               'producers': 0.0,
#               'meat': 0.0,
#               'broilers': 0.0,
#               'wheat': 0.01,
#               'ports': 0.0,
#               'prices': 0.0,
#               'economic': 0.0,
#               'probably': 0.0,
#               'over': 0.0,
#               'steel': 0.0,
#               'have': 0.0,
#               'oil': 0.01,
#               'consumption': 0.0,
#               'current': 0.0,
#               'imports': 0.0,
#               'but': 0.0,
#               'when': 0.0,
#               'at': 0.0,
#               'that': 0.0,
#               'output': 0.0,
#               'merchandise': 0.0,
#               'february': 0.0,
#               'annuities': 0.0,
#               'aegon': 0.0,
#               'insurer': 0.0,
#               'thus': 0.0,
#               'first': 0.0,
#               'funds': 0.0,
#               'energy': 0.0,
#               'moderately': 0.0,
#               'gulf': 0.0,
#               'commitment': 0.0,
#               'company': 0.0,
#               'buying': 0.0,
#               'lead': 0.0,
#               'courier': 0.0,
#               'traders': 0.0,
#               'congress': 0.01,
#               'remained': 0.0,
#               'tobacco': 0.0,
#               'italy': 0.0,
#               'march': 0.0,
#               'retailers': 0.0,
#               'soyoil': 0.0,
#               'congressman': 0.0,
#               'sugar': 0.0,
#               'stockpile': 0.0,
#               'cts': 0.0,
#               'outlook': 0.0,
#               '1986': 0.0,
#               'orange': 0.0,
#               'citrus': 0.0,
#               'ussr': 0.0,
#               'e': 0.0,
#               'supply': 0.0,
#               'exporters': 0.01,
#               'bankruptcy': 0.0,
#               'may': 0.0,
#               'depended': 0.0,
#               'than': 0.0,
#               'dependency': 0.0,
#               'hatching': 0.0,
#               'protein': 0.0,
#               'weekly': 0.0,
#               '19': 0.0,
#               'quality': 0.0,
#               'producing': 0.0,
#               'spot': 0.0,
#               'location': 0.0,
#               'm': 0.0,
#               'discount': 0.0,
#               'bank': 0.01,
#               'money': 0.0,
#               'crude': 0.0,
#               'relected': 0.0,
#               'west': 0.0,
#               'federal': 0.0,
#               'commodities': 0.0,
#               'markets': 0.0,
#               'financial': 0.0,
#               'reflected': 0.0,
#               'budget': 0.0,
#               'is': 0.01,
#               'hurting': 0.0,
#               'it': 0.0,
#               'calls': 0.0,
#               'machinery': 0.0,
#               'green': 0.0,
#               'roastings': 0.0,
#               'european': 0.0,
#               'carries': 0.0,
#               'u': 0.0,
#               'bond': 0.0,
#               'richards': 0.0,
#               'companies': 0.0,
#               'rate': 0.0,
#               'monetary': 0.0,
#               'aggression': 0.0,
#               'industry': 0.0,
#               '27': 0.0,
#               'senate': 0.01,
#               'feeder': 0.0,
#               'tariff': 0.0,
#               'bancorp': 0.0,
#               'employees': 0.0,
#               'trust': 0.0,
#               'by': 0.0,
#               'underwriters': 0.0,
#               'revenues': 0.0,
#               'on': 0.0,
#               'sets': 0.0,
#               'sprint': 0.0,
#               'gas': 0.0,
#               'competitors': 0.0,
#               'plants': 0.0,
#               'cattle': 0.0,
#               'banks': 0.01,
#               'inflation': 0.0,
#               'east': 0.0,
#               'rice': 0.0,
#               'agency': 0.0,
#               'international': 0.0,
#               'customs': 0.0,
#               'bankrupcty': 0.0,
#               'supreme': 0.0,
#               'bid': 0.0,
#               'believed': 0.0,
#               'bill': 0.0,
#               'modernization': 0.0,
#               'soybeans': 0.0,
#               'commerce': 0.0,
#               'urges': 0.0,
#               'grain': 0.01,
#               'put': 0.0,
#               'complaints': 0.0,
#               'they': 0.0,
#               'rose': 0.0,
#               'proposal': 0.0,
#               'foodgrains': 0.0,
#               'reprisals': 0.0,
#               'goods': 0.0,
#               'china': 0.0,
#               'rules': 0.0,
#               'support': 0.0,
#               'central': 0.0,
#               'trading': 0.0,
#               'measures': 0.0,
#               'arm': 0.0,
#               'gnp': 0.0,
#               'south': 0.0,
#               'had': 0.0,
#               'study': 0.0,
#               'consumer': 0.0,
#               'industrial': 0.0,
#               'industries': 0.0,
#               'antitrust': 0.0,
#               'manufacturing': 0.0,
#               'district': 0.0,
#               'rig': 0.0,
#               'drilling': 0.0,
#               'countervailing': 0.0,
#               'under': 0.0,
#               'or': 0.0,
#               'zimmerman': 0.0,
#               'forest': 0.0,
#               'system': 0.0,
#               'lumbermen': 0.0,
#               'lumber': 0.0,
#               'justice': 0.0,
#               'publishing': 0.0,
#               'video': 0.0,
#               'export': 0.0,
#               'allies': 0.0,
#               'frigate': 0.0,
#               'thrift': 0.0,
#               'unprepared': 0.0,
#               'participation': 0.0,
#               'military': 0.0,
#               'action': 0.0,
#               'court': 0.0,
#               'be': 0.0,
#               'hart': 0.0,
#               'did': 0.0,
#               'dollars': 0.0,
#               'since': 0.0,
#               'firm': 0.0,
#               'sectors': 0.0,
#               'investment': 0.0,
#               's': 0.0,
#               'should': 0.0,
#               'gold': 0.0,
#               'salmonellosis': 0.0,
#               'house': 0.0,
#               'allegis': 0.0,
#               'weighs': 0.0,
#               'domestic': 0.0,
#               'ability': 0.0,
#               'gasoline': 0.0,
#               'analysts': 0.0,
#               'stocks': 0.0,
#               'secretary': 0.0,
#               'might': 0.0,
#               'imposed': 0.0,
#               'could': 0.0,
#               'feed': 0.0,
#               'pipeline': 0.0,
#               'flag': 0.0,
#               'arms': 0.0,
#               'warships': 0.0,
#               'inc': 0.0,
#               'holding': 0.0,
#               'barley': 0.0,
#               'flags': 0.0,
#               'forces': 0.0,
#               'wood': 0.0,
#               'april': 0.0,
#               'production': 0.0,
#               'reserve': 0.0,
#               'policy': 0.0,
#               'upgraded': 0.0,
#               'britain': 0.0,
#               'owned': 0.0,
#               'copper': 0.0,
#               'warship': 0.0,
#               'plan': 0.0,
#               'during': 0.0,
#               'tenderloin': 0.0,
#               'striploin': 0.0,
#               'into': 0.0,
#               'deficit': 0.0,
#               'senators': 0.0,
#               'health': 0.0,
#               'personal': 0.0,
#               'league': 0.0,
#               'benchmark': 0.0,
#               'for': 0.0,
#               'cent': 0.0,
#               'superfund': 0.0,
#               'was': 0.0,
#               'chamber': 0.0,
#               'legislators': 0.0,
#               'technology': 0.0,
#               'growth': 0.0,
#               'mandatory': 0.0,
#               'farmers': 0.0,
#               'canada': 0.0,
#               'canadian': 0.0,
#               'estimates': 0.0,
#               'combining': 0.0,
#               'housing': 0.0,
#               'you': 0.0,
#               'shaw': 0.0,
#               'failed': 0.0,
#               'cents': 0.0,
#               'publisher': 0.0,
#               'edible': 0.0,
#               'groundnut': 0.0,
#               'harvest': 0.0,
#               'lenders': 0.0,
#               'thrifts': 0.0,
#               'allowable': 0.0,
#               'synthetic': 0.0,
#               'primary': 0.0,
#               'interests': 0.0,
#               'letter': 0.0,
#               'tankers': 0.0,
#               'navy': 0.0,
#               'business': 0.0,
#               'sec': 0.0,
#               'corporate': 0.0,
#               'asks': 0.0,
#               'assets': 0.0,
#               'ferc': 0.0,
#               'debt': 0.0,
#               'stockbuilding': 0.0,
#               'refiners': 0.0,
#               'remain': 0.0,
#               'pasta': 0.0,
#               'assistant': 0.0,
#               'as': 0.0,
#               'kuwait': 0.0,
#               'iran': 0.0,
#               'moves': 0.0,
#               'plans': 0.0,
#               'says': 0.0,
#               'strike': 0.0,
#               'itself': 0.0,
#               'western': 0.0,
#               'ships': 0.0,
#               'minerals': 0.0,
#               'corporations': 0.0,
#               'withholding': 0.0,
#               'issuers': 0.0,
#               'lt': 0.0,
#               'aluminum': 0.0,
#               'leasing': 0.0,
#               'lomas': 0.0,
#               'reasserts': 0.0,
#               'presence': 0.0,
#               'israel': 0.0,
#               'can': 0.0,
#               'were': 0.0,
#               'yaacobi': 0.0,
#               'soviet': 0.0,
#               'attack': 0.0,
#               'attacked': 0.0,
#               'flagged': 0.0,
#               'equities': 0.0,
#               'shares': 0.0,
#               'bonds': 0.0,
#               'institutional': 0.0,
#               'stock': 0.0,
#               'criticism': 0.0,
#               'deficits': 0.0,
#               'labelling': 0.0,
#               'raid': 0.0,
#               'attacks': 0.0,
#               'sept': 0.0,
#               'claims': 0.0,
#               'coffee': 0.0,
#               'others': 0.0,
#               'roaster': 0.0,
#               'falsely': 0.0,
#               'with': 0.0,
#               'fed': 0.0,
#               'raids': 0.0,
#               'negotiator': 0.0,
#               'lyng': 0.0,
#               'stance': 0.0,
#               'demand': 0.0,
#               'these': 0.0,
#               'halted': 0.0,
#               'takes': 0.0,
#               'ambassador': 0.0,
#               'also': 0.0,
#               'sought': 0.0,
#               'guided': 0.0,
#               'aschoff': 0.0,
#               'operation': 0.0,
#               'virgin': 0.0,
#               'protected': 0.0,
#               'naval': 0.0,
#               'diplomatic': 0.0,
#               'diplomats': 0.0,
#               'analyst': 0.0,
#               'recovery': 0.0,
#               'committed': 0.0,
#               'resolve': 0.0,
#               'retaliatory': 0.0,
#               'involvement': 0.0,
#               'free': 0.0,
#               'israeli': 0.0,
#               'pact': 0.0,
#               'promising': 0.0,
#               'anger': 0.0,
#               'german': 0.0,
#               'grades': 0.0,
#               'joint': 0.0,
#               'destroyers': 0.0,
#               'manufacturers': 0.0,
#               'helicopters': 0.0,
#               'diplomat': 0.0,
#               'intervention': 0.0,
#               'tit': 0.0,
#               'defence': 0.0,
#               'administration': 0.0,
#               'relations': 0.0,
#               'destruction': 0.0,
#               'reaction': 0.0,
#               'must': 0.0,
#               'media': 0.0,
#               'southland': 0.0,
#               'drafts': 0.0,
#               'national': 0.0,
#               'our': 0.0,
#               'source': 0.0,
#               'shelved': 0.0,
#               'sources': 0.0,
#               'earlier': 0.0,
#               'response': 0.0,
#               'apparently': 0.0,
#               'food': 0.0,
#               'businesses': 0.0,
#               'division': 0.0,
#               'television': 0.0,
#               'while': 0.0,
#               'agreed': 0.0,
#               'frustration': 0.0,
#               'consumere': 0.0,
#               'foodservice': 0.0,
#               'shi': 0.0,
#               'builder': 0.0,
#               'against': 0.0,
#               'august': 0.0,
#               'covertible': 0.0,
#               'argentina': 0.0,
#               'cotton': 0.0,
#               'census': 0.0,
#               'operations': 0.0,
#               'home': 0.0,
#               'organic': 0.0,
#               'household': 0.0,
#               'semiconductors': 0.0,
#               'embassy': 0.0,
#               'out': 0.0,
#               'protectionist': 0.0,
#               'reliance': 0.0,
#               'cities': 0.0,
#               'intelligence': 0.0,
#               'experts': 0.0,
#               'both': 0.0,
#               'made': 0.0,
#               'lines': 0.0,
#               'shipping': 0.0,
#               'opposition': 0.0,
#               'hold': 0.0,
#               'maize': 0.0,
#               'botswana': 0.0,
#               'single': 0.0,
#               'president': 0.0,
#               'congressmen': 0.0,
#               'virtually': 0.0,
#               'bases': 0.0,
#               'sales': 0.0,
#               'porsche': 0.0,
#               'accounting': 0.0,
#               'fundscocoa': 0.0,
#               'chemicals': 0.0,
#               'governement': 0.0,
#               'dealers': 0.0,
#               'pl': 0.0,
#               'number': 0.0,
#               'there': 0.0,
#               'price': 0.0,
#               'group': 0.0,
#               'hard': 0.0,
#               'real': 0.0,
#               'workers': 0.0,
#               'sanction': 0.0,
#               'governmental': 0.0,
#               'banker': 0.0,
#               'from': 0.0,
#               'of': 0.0,
#               'chips': 0.0,
#               'sees': 0.0,
#               'expects': 0.0,
#               'bombing': 0.0,
#               'planes': 0.0,
#               'access': 0.0,
#               'alleges': 0.0,
#               'origin': 0.0,
#               'beans': 0.0,
#               'est': 0.0,
#               'allegations': 0.0,
#               'appears': 0.0,
#               'strategy': 0.0,
#               'base': 0.0,
#               'greek': 0.0,
#               '7': 0.0,
#               'treasuries': 0.0,
#               'legislation': 0.0,
#               'delegation': 0.0,
#               'still': 0.0,
#               'remains': 0.0,
#               'issues': 0.0,
#               'mediterranean': 0.0,
#               'refining': 0.0,
#               'refineries': 0.0,
#               'negotiations': 0.0,
#               'auto': 0.0,
#               'cattlemen': 0.0,
#               'dot': 0.0,
#               'airline': 0.0,
#               'credit': 0.0,
#               'tempers': 0.0,
#               'operating': 0.0,
#               'dispute': 0.0,
#               'people': 0.0,
#               'attitude': 0.0,
#               'requests': 0.0,
#               'nor': 0.0,
#               'doubts': 0.0,
#               'currently': 0.0,
#               'negotiators': 0.0,
#               'withdrawal': 0.0,
#               'does': 0.0,
#               'leads': 0.0,
#               'represented': 0.0,
#               'transatlantic': 0.0,
#               'computer': 0.0,
#               'even': 0.0,
#               'leading': 0.0,
#               'senior': 0.0,
#               'index': 0.0,
#               'reported': 0.0,
#               'sugarbeet': 0.0,
#               'beet': 0.0,
#               'europe': 0.0,
#               'visit': 0.0,
#               'suggested': 0.0,
#               'developments': 0.0,
#               'backs': 0.0,
#               'competitiveness': 0.0,
#               'saying': 0.0,
#               'initiative': 0.0,
#               'missiles': 0.0,
#               'distillate': 0.0,
#               'increases': 0.0,
#               'weather': 0.0,
#               'multilateral': 0.0,
#               'eep': 0.0,
#               'vessels': 0.0,
#               '1987': 0.0,
#               'trustee': 0.0,
#               'dry': 0.0,
#               'cost': 0.0,
#               'vegetable': 0.0,
#               'specialty': 0.0,
#               'prime': 0.0,
#               'taiwan': 0.0,
#               'appeals': 0.0,
#               'allis': 0.0,
#               'selling': 0.0,
#               'general': 0.0,
#               'asean': 0.0,
#               'strategic': 0.0,
#               'partner': 0.0,
#               'import': 0.0,
#               'rod': 0.0,
#               'circuit': 0.0,
#               'farms': 0.0,
#               'factories': 0.0,
#               'factory': 0.0,
#               'lard': 0.0,
#               'case': 0.0,
#               'crushing': 0.0,
#               'housewives': 0.0,
#               'penta': 0.0,
#               'package': 0.0,
#               'roasters': 0.0,
#               'poultry': 0.0,
#               'commodity': 0.0,
#               'grains': 0.0,
#               'quotas': 0.0,
#               'primarily': 0.0,
#               'feedgrains': 0.0,
#               'outbreak': 0.0,
#               'top': 0.0,
#               'include': 0.0,
#               'environmental': 0.0,
#               'sentiment': 0.0,
#               'feeling': 0.0,
#               'threats': 0.0,
#               'restrictions': 0.0,
#               'negotiating': 0.0,
#               'france': 0.0,
#               'soft': 0.0,
#               'each': 0.0,
#               'civilian': 0.0,
#               'north': 0.0,
#               'kresge': 0.0,
#               'retail': 0.0,
#               'stores': 0.0,
#               'jobs': 0.0,
#               'gross': 0.0,
#               'scientists': 0.0,
#               'durum': 0.0,
#               'mine': 0.0,
#               'interior': 0.0,
#               'share': 0.0,
#               'bonus': 0.0,
#               'defends': 0.0,
#               'carriers': 0.0,
#               'purchasing': 0.0,
#               'escorts': 0.0,
#               'council': 0.0,
#               'considers': 0.0,
#               'mints': 0.0,
#               'offer': 0.0,
#               'deputy': 0.0,
#               'sorghum': 0.0,
#               'pork': 0.0,
#               'electronics': 0.0,
#               'malta': 0.0,
#               'thinks': 0.0,
#               'mint': 0.0,
#               'certificate': 0.0,
#               'certified': 0.0,
#               'feb': 0.0,
#               'counterparts': 0.0,
#               'ran': 0.0,
#               'urgings': 0.0,
#               '10': 0.0,
#               'effort': 0.0,
#               'regulatory': 0.0,
#               'air': 0.0,
#               'failure': 0.0,
#               'proposed': 0.0,
#               'state': 0.0,
#               'senator': 0.0,
#               'seen': 0.0,
#               'car': 0.0,
#               'recommendations': 0.0,
#               'livestock': 0.0,
#               'tied': 0.0,
#               'protectionism': 0.0,
#               'cooperation': 0.0,
#               'ec': 0.0,
#               'tactic': 0.0,
#               'part': 0.0,
#               'cabinet': 0.0,
#               'reaffirms': 0.0,
#               'subsidiaries': 0.0,
#               'usda': 0.0,
#               'belgian': 0.0,
#               'tells': 0.0,
#               'undersecretary': 0.0,
#               'penetration': 0.0,
#               'processors': 0.0,
#               'luxury': 0.0,
#               'telecommunications': 0.0,
#               'much': 0.0,
#               'legislative': 0.0,
#               'earnings': 0.0,
#               'fell': 0.0,
#               'sector': 0.0,
#               'exploration': 0.0,
#               'requires': 0.0,
#               'okays': 0.0,
#               'agencies': 0.0,
#               'gatt': 0.0,
#               'waiver': 0.0,
#               'barriers': 0.0,
#               'polyethylene': 0.0,
#               'customers': 0.0,
#               'growers': 0.0,
#               'compared': 0.0,
#               'recognises': 0.0,
#               'marketing': 0.0,
#               'law': 0.0,
#               'interstate': 0.0,
#               'crop': 0.0,
#               'clients': 0.0,
#               '29': 0.0,
#               'subsidies': 0.0,
#               'employment': 0.0,
#               'non': 0.0,
#               'durable': 0.0,
#               'property': 0.0,
#               'believes': 0.0,
#               'are': 0.0,
#               'futures': 0.0,
#               'processing': 0.0,
#               'ban': 0.0,
#               'dismissal': 0.0,
#               'facilities': 0.0,
#               'fsical': 0.0,
#               'agreement': 0.0,
#               'poehl': 0.0,
#               'provides': 0.0,
#               'fiscal': 0.0,
#               'ruling': 0.0,
#               'properties': 0.0,
#               'insurance': 0.0,
#               'transportation': 0.0,
#               'ct': 0.0,
#               'zinc': 0.0,
#               'slab': 0.0,
#               'exceeded': 0.0,
#               'productivity': 0.0,
#               'turnover': 0.0,
#               'accord': 0.0,
#               'an': 0.0,
#               'payments': 0.0,
#               'wallcoverings': 0.0,
#               'dependence': 0.0,
#               'sells': 0.0,
#               'tax': 0.0,
#               'intervened': 0.0,
#               'set': 0.0,
#               'kick': 0.0,
#               'authorities': 0.0,
#               'bought': 0.0,
#               'down': 0.0,
#               'spokesman': 0.0,
#               'consortium': 0.0,
#               'who': 0.0,
#               'bean': 0.0,
#               'pension': 0.0,
#               'political': 0.0,
#               'colombia': 0.0,
#               'activity': 0.0,
#               'airlines': 0.0,
#               'citizens': 0.0,
#               '4th': 0.0,
#               'increased': 0.0,
#               'hosuing': 0.0,
#               'completions': 0.0,
#               'rivals': 0.0,
#               'counterpart': 0.0,
#               'brokerage': 0.0,
#               'produced': 0.0,
#               'duty': 0.0,
#               'purchases': 0.0,
#               'conservation': 0.0,
#               'plays': 0.0,
#               'combined': 0.0,
#               'govt': 0.0,
#               'natural': 0.0,
#               'automaker': 0.0,
#               'greater': 0.0,
#               'wine': 0.0,
#               'plane': 0.0,
#               'makers': 0.0,
#               'high': 0.0,
#               'supercomputers': 0.0,
#               'increase': 0.0,
#               'lawyer': 0.0,
#               'hit': 0.0,
#               'farmland': 0.0,
#               'farming': 0.0,
#               'supercomputer': 0.0,
#               'silas': 0.0,
#               'exporter': 0.0,
#               'actions': 0.0,
#               'caused': 0.0,
#               'objections': 0.0,
#               'microchip': 0.0,
#               'fears': 0.0,
#               'silicon': 0.0,
#               'lends': 0.0,
#               'two': 0.0,
#               'producer': 0.0,
#               'edition': 0.0,
#               'editiion': 0.0,
#               'report': 0.0,
#               'makes': 0.0,
#               'meets': 0.0,
#               'net': 0.0,
#               'design': 0.0,
#               'yesterday': 0.0,
#               'states': 0.0,
#               'cable': 0.0,
#               'gallon': 0.0,
#               'responded': 0.0,
#               'british': 0.0,
#               'bhp': 0.0,
#               'hamburg': 0.0,
#               'peru': 0.0,
#               'foreign': 0.0,
#               'amounted': 0.0,
#               'drop': 0.0,
#               'opec': 0.0,
#               'enforcement': 0.0,
#               'soy': 0.0,
#               'effective': 0.0,
#               'acreage': 0.0,
#               'savings': 0.0,
#               'forum': 0.0,
#               'options': 0.0,
#               'concerning': 0.0,
#               'cityfed': 0.0,
#               'chipmakers': 0.0,
#               'heating': 0.0,
#               'steps': 0.0,
#               'seems': 0.0,
#               'now': 0.0,
#               'expansion': 0.0,
#               'although': 0.0,
#               'minus': 0.0,
#               'side': 0.0,
#               'conglomerate': 0.0,
#               'direct': 0.0,
#               '0': 0.0,
#               'rep': 0.0,
#               'fibre': 0.0,
#               'corp': 0.0,
#               'warns': 0.0,
#               'fhl': 0.0,
#               'automakers': 0.0,
#               'tallow': 0.0,
#               'certificates': 0.0,
#               '43': 0.0,
#               'brokers': 0.0,
#               'regional': 0.0,
#               'expired': 0.0,
#               'morgan': 0.0,
#               'about': 0.0,
#               'dropped': 0.0,
#               'feedlots': 0.0,
#               'coins': 0.0,
#               'gelco': 0.0,
#               'designs': 0.0,
#               'rigs': 0.0,
#               'brokerages': 0.0,
#               'waste': 0.0,
#               'coast': 0.0,
#               'delivery': 0.0,
#               'life': 0.0,
#               'requirements': 0.0,
#               'tin': 0.0,
#               'norstar': 0.0,
#               'recording': 0.0,
#               'copyright': 0.0,
#               'departments': 0.0,
#               'long': 0.0,
#               'competition': 0.0,
#               '17': 0.0,
#               '5': 0.0,
#               'oecd': 0.0,
#               'subsidy': 0.0,
#               'after': 0.0,
#               'drive': 0.0,
#               'data': 0.0,
#               'pleas': 0.0,
#               'entertainment': 0.0,
#               'taxpayer': 0.0,
#               'duties': 0.0,
#               'concerns': 0.0,
#               'rejection': 0.0,
#               'we': 0.0,
#               'drug': 0.0,
#               'later': 0.0,
#               'transit': 0.0,
#               'program': 0.0,
#               'insider': 0.0,
#               'target': 0.0,
#               'proposals': 0.0,
#               'efforts': 0.0,
#               'aircraft': 0.0,
#               'indian': 0.0,
#               'mideast': 0.0,
#               'alfaro': 0.0,
#               'needs': 0.0,
#               'equal': 0.0,
#               'educational': 0.0,
#               'pharmacologist': 0.0,
#               'prescriptions': 0.0,
#               'approves': 0.0,
#               'realised': 0.0,
#               'broke': 0.0,
#               'presented': 0.0,
#               'views': 0.0,
#               'distribution': 0.0,
#               'epxertise': 0.0,
#               'fish': 0.0,
#               'shipments': 0.0,
#               'frozen': 0.0,
#               'cold': 0.0,
#               'excluding': 0.0,
#               'refinery': 0.0,
#               'refined': 0.0,
#               'due': 0.0,
#               'supplied': 0.0,
#               'oilseeds': 0.0,
#               'breeding': 0.0,
#               'lower': 0.0,
#               'consumers': 0.0,
#               'loss': 0.0,
#               'proved': 0.0,
#               'new': 0.0,
#               'goes': 0.0,
#               'auctions': 0.0,
#               'along': 0.0,
#               'super': 0.0,
#               '21': 0.0,
#               'brass': 0.0,
#               'accounted': 0.0,
#               'like': 0.0,
#               'wickes': 0.0,
#               'press': 0.0,
#               'understanding': 0.0,
#               'gallons': 0.0,
#               'tonka': 0.0,
#               'prepared': 0.0,
#               'lost': 0.0,
#               'capital': 0.0,
#               'willingness': 0.0,
#               'judgment': 0.0,
#               'places': 0.0,
#               'wang': 0.0,
#               'vice': 0.0,
#               'bilateral': 0.0,
#               'likely': 0.0,
#               'offers': 0.0,
#               'interference': 0.0,
#               'helped': 0.0,
#               'any': 0.0,
#               'widened': 0.0,
#               'plains': 0.0,
#               'jobless': 0.0,
#               'disclosures': 0.0,
#               'distillates': 0.0,
#               'card': 0.0,
#               'industory': 0.0,
#               'closing': 0.0,
#               'via': 0.0,
#               'limits': 0.0,
#               'cannot': 0.0,
#               'mortgage': 0.0,
#               'bankcard': 0.0,
#               'cane': 0.0,
#               'potash': 0.0,
#               'most': 0.0,
#               'axworthy': 0.0,
#               'what': 0.0,
#               'amd': 0.0,
#               'autoparts': 0.0,
#               'major': 0.0,
#               'profit': 0.0,
#               'projects': 0.0,
#               'brown': 0.0,
#               'rising': 0.0,
#               'automobile': 0.0,
#               'figures': 0.0,
#               'within': 0.0,
#               'fundswaste': 0.0,
#               ...}),
#  ('s', 'japan'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'agreement': 0.07,
#               'and': 0.11,
#               'britain': 0.02,
#               'canada': 0.02,
#               'economic': 0.04,
#               'foreign': 0.02,
#               'investigation': 0.04,
#               'micro': 0.02,
#               'microchip': 0.04,
#               'not': 0.02,
#               'pact': 0.07,
#               'relations': 0.04,
#               'rift': 0.02,
#               's': 0.07,
#               'semiconductor': 0.04,
#               'the': 0.02,
#               'trade': 0.19,
#               'verging': 0.04,
#               'west': 0.16}),
#  ('japan', 'rift'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'mounting': 1.0}),
#  ('rift',
#   'mounting'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'trade': 1.0}),
#  ('mounting',
#   'trade'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'friction': 0.67,
#               'tension': 0.33}),
#  ('trade',
#   'friction'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 0.28,
#               'between': 0.17,
#               'could': 0.06,
#               'diplomacy': 0.06,
#               'flared': 0.06,
#               'is': 0.06,
#               'japanese': 0.06,
#               'the': 0.06,
#               'threatens': 0.06,
#               'unless': 0.06,
#               'will': 0.06,
#               'with': 0.06}),
#  ('friction',
#   'between'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#  ('between',
#   'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'15': 0.0,
#               '2': 0.0,
#               '3': 0.0,
#               'acceptance': 0.0,
#               'bank': 0.01,
#               'beginning': 0.0,
#               'big': 0.01,
#               'british': 0.0,
#               'bundesbank': 0.0,
#               'canadian': 0.0,
#               'candidates': 0.0,
#               'cenepa': 0.01,
#               'central': 0.0,
#               'coast': 0.0,
#               'commercial': 0.0,
#               'commission': 0.01,
#               'community': 0.01,
#               'companies': 0.01,
#               'company': 0.0,
#               'copper': 0.0,
#               'countries': 0.0,
#               'currency': 0.0,
#               'declaration': 0.0,
#               'demands': 0.0,
#               'dollar': 0.01,
#               'dutch': 0.0,
#               'ebullient': 0.0,
#               'ec': 0.03,
#               'employers': 0.01,
#               'end': 0.0,
#               'european': 0.01,
#               'factories': 0.0,
#               'fall': 0.0,
#               'fed': 0.0,
#               'federal': 0.01,
#               'finance': 0.0,
#               'first': 0.0,
#               'five': 0.0,
#               'government': 0.01,
#               'group': 0.01,
#               'growth': 0.0,
#               'guilder': 0.01,
#               'heaviest': 0.0,
#               'increased': 0.0,
#               'indian': 0.0,
#               'japanese': 0.0,
#               'large': 0.01,
#               'latest': 0.0,
#               'leading': 0.0,
#               'loan': 0.0,
#               'lt': 0.0,
#               'major': 0.0,
#               'ministry': 0.0,
#               'new': 0.0,
#               'old': 0.01,
#               'omani': 0.0,
#               'origins': 0.0,
#               'parent': 0.0,
#               'parties': 0.01,
#               'philippines': 0.0,
#               'pork': 0.0,
#               'premium': 0.0,
#               'pressures': 0.0,
#               'prices': 0.0,
#               'prime': 0.02,
#               'producers': 0.0,
#               'purchase': 0.0,
#               'report': 0.01,
#               'second': 0.0,
#               'secured': 0.0,
#               'seven': 0.01,
#               'six': 0.01,
#               'start': 0.01,
#               'study': 0.0,
#               'total': 0.0,
#               'two': 0.36,
#               'u': 0.09,
#               'ugandan': 0.0,
#               'union': 0.01,
#               'united': 0.07,
#               'use': 0.0,
#               'utility': 0.0,
#               'volume': 0.0,
#               'white': 0.0,
#               'wilkinson': 0.0,
#               'world': 0.01}),
#  ('the', 'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'k': 0.07, 'n': 0.01, 's': 0.93}),
#  ('s', 'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'35': 0.0,
#               'a': 0.02,
#               'abroad': 0.0,
#               'also': 0.0,
#               'amalgamated': 0.0,
#               'amerada': 0.0,
#               'argentine': 0.01,
#               'asia': 0.01,
#               'atlas': 0.0,
#               'australia': 0.01,
#               'bp': 0.0,
#               'brazil': 0.01,
#               'britain': 0.02,
#               'british': 0.02,
#               'cain': 0.0,
#               'canada': 0.02,
#               'canadian': 0.01,
#               'china': 0.0,
#               'chinese': 0.0,
#               'criticized': 0.0,
#               'early': 0.01,
#               'ec': 0.02,
#               'elsewhere': 0.01,
#               'europe': 0.04,
#               'european': 0.03,
#               'export': 0.01,
#               'exxon': 0.01,
#               'few': 0.0,
#               'foreign': 0.02,
#               'from': 0.0,
#               'german': 0.0,
#               'gordon': 0.0,
#               'had': 0.01,
#               'has': 0.01,
#               'hong': 0.0,
#               'hospital': 0.0,
#               'in': 0.01,
#               'is': 0.0,
#               'its': 0.0,
#               'japan': 0.1,
#               'japanese': 0.04,
#               'korea': 0.0,
#               'kuwait': 0.01,
#               'l': 0.02,
#               'lead': 0.0,
#               'london': 0.0,
#               'losing': 0.0,
#               'major': 0.0,
#               'malaysia': 0.0,
#               'most': 0.0,
#               'nato': 0.0,
#               'netherlands': 0.0,
#               'new': 0.0,
#               'non': 0.01,
#               'north': 0.0,
#               'oecd': 0.0,
#               'on': 0.0,
#               'one': 0.0,
#               'other': 0.02,
#               'others': 0.0,
#               'overseas': 0.02,
#               'p': 0.01,
#               'pacific': 0.0,
#               'pioneer': 0.0,
#               'progressive': 0.0,
#               'raise': 0.0,
#               'related': 0.0,
#               'remained': 0.0,
#               'rising': 0.0,
#               'rupert': 0.0,
#               'seek': 0.0,
#               'south': 0.0,
#               'soviet': 0.02,
#               'that': 0.0,
#               'the': 0.06,
#               'they': 0.0,
#               'third': 0.0,
#               'tight': 0.0,
#               'to': 0.0,
#               'tony': 0.0,
#               'u': 0.02,
#               'ultimately': 0.0,
#               'united': 0.0,
#               'up': 0.0,
#               'ussr': 0.01,
#               'w': 0.03,
#               'west': 0.13,
#               'with': 0.01,
#               'world': 0.0,
#               'would': 0.0,
#               'yeutter': 0.0}),
#  ('and', 'japan'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'a': 0.02,
#               'and': 0.03,
#               'are': 0.04,
#               'at': 0.01,
#               'became': 0.01,
#               'believe': 0.01,
#               'but': 0.02,
#               'concerning': 0.02,
#               'could': 0.01,
#               'had': 0.01,
#               'harder': 0.01,
#               'hardest': 0.02,
#               'has': 0.02,
#               'have': 0.03,
#               'he': 0.01,
#               'is': 0.01,
#               'it': 0.02,
#               'japan': 0.01,
#               'look': 0.01,
#               'made': 0.01,
#               'meanwhile': 0.01,
#               'might': 0.02,
#               'must': 0.02,
#               'needed': 0.01,
#               'officials': 0.01,
#               'on': 0.06,
#               'only': 0.01,
#               'or': 0.02,
#               'over': 0.02,
#               'rather': 0.01,
#               'remain': 0.01,
#               's': 0.06,
#               'set': 0.02,
#               'should': 0.01,
#               'stemming': 0.01,
#               'stimulating': 0.01,
#               'succeed': 0.01,
#               'that': 0.01,
#               'the': 0.04,
#               'they': 0.01,
#               'to': 0.11,
#               'u': 0.01,
#               'using': 0.01,
#               'was': 0.01,
#               'we': 0.01,
#               'were': 0.03,
#               'which': 0.01,
#               'who': 0.01,
#               'will': 0.06,
#               'williams': 0.01,
#               'with': 0.03,
#               'would': 0.02,
#               'yu': 0.01}),
#  ('japan', 'has'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'agreed': 0.02,
#               'already': 0.07,
#               'also': 0.02,
#               'asked': 0.02,
#               'assured': 0.03,
#               'been': 0.07,
#               'come': 0.03,
#               'complained': 0.02,
#               'cut': 0.05,
#               'done': 0.02,
#               'failed': 0.03,
#               'far': 0.02,
#               'frequently': 0.02,
#               'genuinely': 0.02,
#               'launched': 0.02,
#               'little': 0.05,
#               'no': 0.1,
#               'not': 0.05,
#               'purchased': 0.02,
#               'raised': 0.02,
#               'rejected': 0.02,
#               'resulted': 0.02,
#               'said': 0.07,
#               'so': 0.02,
#               'sought': 0.02,
#               'stopped': 0.05,
#               'the': 0.09,
#               'violated': 0.02,
#               'withdrawn': 0.02}),
#  ('has', 'raised'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'61': 0.04,
#               'concern': 0.04,
#               'dependence': 0.04,
#               'fears': 0.08,
#               'his': 0.04,
#               'its': 0.52,
#               'prices': 0.04,
#               'the': 0.16,
#               'u': 0.04}),
#  ('raised',
#   'fears'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'among': 0.25,
#               'of': 0.25,
#               'on': 0.25,
#               'the': 0.25}),
#  ('fears',
#   'among'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'many': 1.0}),
#  ('among', 'many'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'international': 0.5, 'of': 0.5}),
#  ('many', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'122': 0.03,
#               'asia': 0.03,
#               'its': 0.11,
#               'our': 0.03,
#               'the': 0.56,
#               'them': 0.08,
#               'these': 0.03,
#               'those': 0.06,
#               'trailways': 0.03,
#               'us': 0.03,
#               'whom': 0.03}),
#  ('of', 'asia'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'and': 0.33, 's': 0.67}),
#  ('asia', 's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'best': 0.2,
#               'exporting': 0.2,
#               'four': 0.2,
#               'largest': 0.2,
#               'two': 0.2}),
#  ('s',
#   'exporting'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'nations': 1.0}),
#  ('exporting',
#   'nations'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'australia': 0.25,
#               'like': 0.25,
#               'that': 0.25,
#               'to': 0.25}),
#  ('nations',
#   'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'are': 0.2,
#               'currency': 0.1,
#               'have': 0.3,
#               'pact': 0.1,
#               'relative': 0.1,
#               'the': 0.1,
#               'washington': 0.1}),
#  ('that', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'0': 0.0,
#               '1': 0.0,
#               '10': 0.0,
#               '13': 0.0,
#               '14': 0.0,
#               '15': 0.0,
#               '1979': 0.0,
#               '1980': 0.0,
#               '1986': 0.0,
#               '1987': 0.0,
#               '1988': 0.0,
#               '23': 0.0,
#               '27': 0.0,
#               '29': 0.0,
#               '4': 0.0,
#               '497': 0.0,
#               '74': 0.0,
#               'ability': 0.0,
#               'accident': 0.0,
#               'accord': 0.0,
#               'accumulated': 0.0,
#               'acp': 0.0,
#               'acquired': 0.0,
#               'acquisition': 0.0,
#               'action': 0.0,
#               'addition': 0.0,
#               'administration': 0.01,
#               'adoption': 0.0,
#               'aerospace': 0.0,
#               'agreement': 0.0,
#               'agriculture': 0.0,
#               'ailing': 0.0,
#               'aim': 0.0,
#               'airline': 0.0,
#               'allies': 0.0,
#               'allocations': 0.0,
#               'alteration': 0.0,
#               'amended': 0.0,
#               'american': 0.0,
#               'americans': 0.0,
#               'amount': 0.0,
#               'amounts': 0.0,
#               'annualised': 0.0,
#               'apparent': 0.0,
#               'appeal': 0.0,
#               'appetite': 0.0,
#               'application': 0.0,
#               'arctic': 0.0,
#               'area': 0.0,
#               'armed': 0.0,
#               'arms': 0.0,
#               'association': 0.0,
#               'attack': 0.0,
#               'attitude': 0.0,
#               'auction': 0.0,
#               'authorities': 0.0,
#               'average': 0.0,
#               'backwardation': 0.0,
#               'ban': 0.0,
#               'bank': 0.01,
#               'bankers': 0.0,
#               'banks': 0.0,
#               'basic': 0.0,
#               'battle': 0.0,
#               'because': 0.0,
#               'benefits': 0.0,
#               'best': 0.0,
#               'bid': 0.0,
#               'bidding': 0.0,
#               'bill': 0.0,
#               'board': 0.0,
#               'bond': 0.0,
#               'braking': 0.0,
#               'brazilian': 0.0,
#               'britannia': 0.0,
#               'british': 0.0,
#               'budget': 0.0,
#               'buffer': 0.0,
#               'bulk': 0.0,
#               'bundesbank': 0.01,
#               'burro': 0.0,
#               'buy': 0.0,
#               'cairns': 0.0,
#               'canadian': 0.0,
#               'cash': 0.0,
#               'cbt': 0.0,
#               'central': 0.01,
#               'certificates': 0.0,
#               'chancellor': 0.0,
#               'chances': 0.0,
#               'changes': 0.0,
#               'chemical': 0.0,
#               'chernobyl': 0.0,
#               'chinese': 0.0,
#               'choice': 0.0,
#               'civil': 0.0,
#               'class': 0.0,
#               'clevebaco': 0.0,
#               'cmb': 0.0,
#               'cocoa': 0.0,
#               'coffee': 0.0,
#               'combination': 0.0,
#               'combined': 0.0,
#               'commerce': 0.0,
#               'commission': 0.01,
#               'commitment': 0.0,
#               'commitments': 0.0,
#               'common': 0.0,
#               'community': 0.0,
#               'companies': 0.0,
#               'company': 0.03,
#               'congress': 0.0,
#               'conservative': 0.0,
#               'consortium': 0.0,
#               'constant': 0.0,
#               'consumer': 0.0,
#               'contingency': 0.0,
#               'contribution': 0.0,
#               'controlled': 0.0,
#               'correction': 0.0,
#               'cost': 0.0,
#               'costs': 0.0,
#               'country': 0.01,
#               'court': 0.0,
#               'crisis': 0.0,
#               'criticism': 0.0,
#               'currencies': 0.0,
#               'currency': 0.0,
#               'current': 0.01,
#               'cutbacks': 0.0,
#               'damage': 0.0,
#               'danger': 0.0,
#               'date': 0.0,
#               'deal': 0.0,
#               'dealer': 0.0,
#               'debt': 0.0,
#               'debtholders': 0.0,
#               'december': 0.0,
#               'decision': 0.0,
#               'decks': 0.0,
#               'decline': 0.0,
#               'deficit': 0.0,
#               'demand': 0.0,
#               'democratic': 0.0,
#               'department': 0.0,
#               'deterioration': 0.0,
#               'developed': 0.0,
#               'dinar': 0.0,
#               'discount': 0.0,
#               'dispute': 0.0,
#               'dividend': 0.0,
#               'document': 0.0,
#               'dollar': 0.03,
#               'dollars': 0.0,
#               'domestic': 0.0,
#               'donalda': 0.0,
#               'door': 0.0,
#               'dot': 0.0,
#               'downtrend': 0.0,
#               'downward': 0.0,
#               'draining': 0.0,
#               'draw': 0.0,
#               'drilling': 0.0,
#               'drop': 0.0,
#               'drought': 0.0,
#               'dutch': 0.0,
#               'e': 0.0,
#               'early': 0.0,
#               'ec': 0.01,
#               'economic': 0.0,
#               'economy': 0.01,
#               'eep': 0.0,
#               'effect': 0.0,
#               'effectiveness': 0.0,
#               'effects': 0.0,
#               'eight': 0.0,
#               'elimination': 0.0,
#               'employment': 0.0,
#               'energy': 0.0,
#               'epa': 0.0,
#               'estimated': 0.0,
#               'estimates': 0.0,
#               'eurofer': 0.0,
#               'european': 0.0,
#               'europeans': 0.0,
#               'evergo': 0.0,
#               'exchange': 0.0,
#               'existence': 0.0,
#               'existing': 0.0,
#               'expansionary': 0.0,
#               'export': 0.0,
# ...
#               'consolidated': 0.0,
#               'consumption': 0.0,
#               'cytrx': 0.0,
#               'december': 0.04,
#               'discounted': 0.0,
#               'dlr': 0.0,
#               'dollar': 0.0,
#               'durables': 0.0,
#               'each': 0.0,
#               'early': 0.01,
#               'feb': 0.01,
#               'february': 0.14,
#               'first': 0.01,
#               'fiscal': 0.0,
#               'four': 0.0,
#               'fourth': 0.0,
#               'france': 0.0,
#               'fresh': 0.0,
#               'fuels': 0.0,
#               'generic': 0.0,
#               'guangdong': 0.0,
#               'hapag': 0.0,
#               'hard': 0.0,
#               'hong': 0.0,
#               'income': 0.0,
#               'increased': 0.0,
#               'indonesia': 0.0,
#               'industrial': 0.0,
#               'international': 0.0,
#               'italy': 0.0,
#               'its': 0.0,
#               'jan': 0.0,
#               'janbiotechnology': 0.0,
#               'janu': 0.0,
#               'january': 0.13,
#               'januaryaustralian': 0.0,
#               'januarymoto': 0.0,
#               'japan': 0.0,
#               'july': 0.0,
#               'june': 0.0,
#               'laenderbank': 0.0,
#               'line': 0.0,
#               'lt': 0.0,
#               'm': 0.0,
#               'machinery': 0.0,
#               'manufacturing': 0.0,
#               'march': 0.03,
#               'may': 0.02,
#               'mid': 0.0,
#               'mo': 0.0,
#               'month': 0.0,
#               'net': 0.0,
#               'nine': 0.0,
#               'non': 0.0,
#               'november': 0.01,
#               'oct': 0.0,
#               'october': 0.0,
#               'oil': 0.0,
#               'one': 0.0,
#               'order': 0.0,
#               'part': 0.0,
#               'personal': 0.0,
#               'pharmaceuticals': 0.0,
#               'plantings': 0.0,
#               'previous': 0.0,
#               'private': 0.0,
#               'profits': 0.0,
#               'public': 0.0,
#               'quarter': 0.0,
#               'real': 0.01,
#               'return': 0.0,
#               'rubber': 0.0,
#               'same': 0.0,
#               'september': 0.01,
#               'seven': 0.0,
#               'soybean': 0.0,
#               'spite': 0.0,
#               'stock': 0.0,
#               'tax': 0.0,
#               'that': 0.0,
#               'the': 0.16,
#               'their': 0.0,
#               'this': 0.0,
#               'three': 0.0,
#               'today': 0.0,
#               'tonnage': 0.0,
#               'total': 0.0,
#               'value': 0.0,
#               'vernitron': 0.0,
#               'volume': 0.0,
#               'week': 0.0,
#               'west': 0.0,
#               'year': 0.0,
#               'yen': 0.0}),
#  ('quarter',
#   'due'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'primarily': 0.14,
#               'to': 0.86}),
#  ('lower', 'oil'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'and': 0.21,
#               'exports': 0.05,
#               'price': 0.05,
#               'prices': 0.58,
#               'revenues': 0.05,
#               'traders': 0.05}),
#  ('oil', 'prices'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'18': 0.0,
#               '50': 0.01,
#               'above': 0.0,
#               'added': 0.0,
#               'agriculture': 0.0,
#               'american': 0.0,
#               'an': 0.01,
#               'and': 0.12,
#               'announced': 0.0,
#               'are': 0.02,
#               'around': 0.0,
#               'as': 0.0,
#               'at': 0.02,
#               'average': 0.0,
#               'averaging': 0.0,
#               'below': 0.0,
#               'but': 0.02,
#               'by': 0.01,
#               'called': 0.0,
#               'caused': 0.0,
#               'central': 0.0,
#               'china': 0.0,
#               'cif': 0.0,
#               'citgo': 0.0,
#               'combined': 0.0,
#               'conoco': 0.0,
#               'continue': 0.0,
#               'could': 0.01,
#               'coupled': 0.01,
#               'declined': 0.0,
#               'do': 0.0,
#               'don': 0.0,
#               'dropped': 0.01,
#               'dropping': 0.01,
#               'during': 0.01,
#               'early': 0.01,
#               'energy': 0.01,
#               'experienced': 0.0,
#               'fell': 0.01,
#               'for': 0.01,
#               'foreign': 0.0,
#               'from': 0.02,
#               'fuel': 0.0,
#               'german': 0.01,
#               'government': 0.0,
#               'had': 0.01,
#               'has': 0.0,
#               'have': 0.01,
#               'he': 0.02,
#               'heating': 0.0,
#               'hold': 0.01,
#               'however': 0.0,
#               'in': 0.03,
#               'industrial': 0.0,
#               'industry': 0.0,
#               'irna': 0.0,
#               'is': 0.01,
#               'it': 0.01,
#               'jumardi': 0.0,
#               'kept': 0.0,
#               'keswick': 0.0,
#               'king': 0.01,
#               'lange': 0.0,
#               'largely': 0.0,
#               'last': 0.02,
#               'lawson': 0.01,
#               'lost': 0.0,
#               'low': 0.01,
#               'made': 0.01,
#               'matching': 0.0,
#               'monday': 0.01,
#               'national': 0.0,
#               'nazer': 0.01,
#               'net': 0.0,
#               'netback': 0.0,
#               'of': 0.01,
#               'oil': 0.01,
#               'on': 0.01,
#               'one': 0.0,
#               'opec': 0.0,
#               'over': 0.0,
#               'palm': 0.0,
#               'permanently': 0.0,
#               'phillips': 0.0,
#               'plunged': 0.01,
#               'precluded': 0.0,
#               'rallied': 0.01,
#               'rather': 0.0,
#               'reached': 0.0,
#               'recovering': 0.0,
#               'remain': 0.0,
#               'remains': 0.01,
#               'rise': 0.0,
#               'rises': 0.0,
#               'rose': 0.02,
#               'said': 0.01,
#               'security': 0.0,
#               'she': 0.0,
#               'sheikh': 0.01,
#               'should': 0.02,
#               'since': 0.0,
#               'slipped': 0.0,
#               'spiralled': 0.0,
#               'strong': 0.01,
#               'such': 0.0,
#               'surged': 0.0,
#               'tenneco': 0.0,
#               'texaco': 0.0,
#               'the': 0.04,
#               'they': 0.0,
#               'this': 0.01,
#               'to': 0.04,
#               'top': 0.0,
#               'tumbled': 0.0,
#               'tumbling': 0.0,
#               'union': 0.0,
#               'up': 0.01,
#               'was': 0.02,
#               'were': 0.02,
#               'which': 0.02,
#               'will': 0.03,
#               'with': 0.0,
#               'woodside': 0.0,
#               'would': 0.03}),
#  ('prices', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'administration': 0.01,
#               'agriculture': 0.01,
#               'analysts': 0.01,
#               'average': 0.01,
#               'bank': 0.03,
#               'basis': 0.01,
#               'belcher': 0.01,
#               'canadian': 0.01,
#               'commission': 0.01,
#               'committee': 0.01,
#               'company': 0.09,
#               'consensus': 0.01,
#               'corn': 0.01,
#               'current': 0.01,
#               'debt': 0.01,
#               'department': 0.01,
#               'dow': 0.01,
#               'driving': 0.01,
#               'economy': 0.01,
#               'four': 0.01,
#               'government': 0.01,
#               'group': 0.01,
#               'higher': 0.01,
#               'icco': 0.01,
#               'index': 0.01,
#               'international': 0.01,
#               'iraqi': 0.01,
#               'leaf': 0.01,
#               'malaysian': 0.01,
#               'mexican': 0.01,
#               'ministry': 0.01,
#               'narrowing': 0.01,
#               'need': 0.03,
#               'newest': 0.01,
#               'official': 0.01,
#               'officials': 0.03,
#               'onset': 0.01,
#               'partnership': 0.01,
#               'past': 0.01,
#               'remaining': 0.01,
#               'report': 0.03,
#               'requests': 0.01,
#               'results': 0.01,
#               'senator': 0.01,
#               'small': 0.01,
#               'source': 0.01,
#               'sources': 0.06,
#               'soviets': 0.01,
#               'spokesman': 0.01,
#               'state': 0.04,
#               'statement': 0.01,
#               'survey': 0.03,
#               'tapioca': 0.01,
#               'three': 0.01,
#               'two': 0.01,
#               'u': 0.05,
#               'underlying': 0.01}),
#  ('the',
#   'department'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'aid': 0.0,
#               'allowed': 0.0,
#               'also': 0.02,
#               'and': 0.0,
#               'asked': 0.0,
#               'attributed': 0.0,
#               'before': 0.0,
#               'but': 0.0,
#               'called': 0.0,
#               'citing': 0.0,
#               'consulted': 0.0,
#               'declined': 0.0,
#               'earlier': 0.0,
#               'eia': 0.0,
#               'estimated': 0.01,
#               'fell': 0.0,
#               'forecast': 0.0,
#               'had': 0.01,
#               'has': 0.01,
#               'is': 0.01,
#               'last': 0.0,
#               'may': 0.0,
#               'must': 0.0,
#               'no': 0.0,
#               'noted': 0.02,
#               'of': 0.13,
#               'officials': 0.0,
#               'previously': 0.02,
#               'raised': 0.01,
#               'reported': 0.01,
#               'revised': 0.0,
#               's': 0.06,
#               'said': 0.61,
#               'to': 0.01,
#               'told': 0.0,
#               'usda': 0.0,
#               'was': 0.01,
#               'which': 0.0,
#               'would': 0.0,
#               'yesterday': 0.0}),
#  ('said', 'first'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'bank': 0.02,
#               'boston': 0.02,
#               'central': 0.05,
#               'chicago': 0.02,
#               'consignments': 0.02,
#               'control': 0.02,
#               'data': 0.02,
#               'federal': 0.05,
#               'financial': 0.02,
#               'half': 0.05,
#               'in': 0.02,
#               'interstate': 0.05,
#               'marathon': 0.02,
#               'national': 0.07,
#               'planting': 0.02,
#               'quarter': 0.42,
#               'railroad': 0.02,
#               'the': 0.02,
#               'tuskaloosa': 0.02,
#               'union': 0.02}),
#  ('quarter',
#   'exports'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'expanded': 0.2,
#               'fell': 0.2,
#               'of': 0.2,
#               'rose': 0.2,
#               'to': 0.2}),
#  ('exports',
#   'expanded'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 1.0}),
#  ('expanded',
#   'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'10': 0.25,
#               '60': 0.25,
#               'feedgrains': 0.25,
#               'include': 0.25}),
#  ('to', '60'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'0': 0.04,
#               '1': 0.04,
#               '50': 0.04,
#               '6': 0.04,
#               '629': 0.04,
#               '700': 0.04,
#               'billion': 0.04,
#               'business': 0.04,
#               'cts': 0.09,
#               'dlrs': 0.04,
#               'mln': 0.26,
#               'mph': 0.04,
#               'pct': 0.22}),
#  ('60', '6'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'billion': 0.14, 'mln': 0.71, 'mlnaloette': 0.14}),
#  ('from', '56'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'0': 0.14, '6': 0.14, 'cents': 0.14, 'cts': 0.14, 'pct': 0.43}),
#  ('56', '6'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'billion': 0.17, 'mln': 0.67, 'mlnnorth': 0.17}),
#  ('billion',
#   'export'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'growth': 1.0}),
#  ('export',
#   'growth'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'beryl': 0.08,
#               'caused': 0.08,
#               'dual': 0.08,
#               'has': 0.08,
#               'in': 0.08,
#               'must': 0.08,
#               'to': 0.17,
#               'was': 0.17,
#               'were': 0.08,
#               'will': 0.08}),
#  ('growth', 'was'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'1': 0.03,
#               '11': 0.07,
#               '15': 0.03,
#               '2': 0.03,
#               '21': 0.03,
#               '32': 0.03,
#               'a': 0.03,
#               'attributed': 0.03,
#               'broad': 0.05,
#               'calculated': 0.03,
#               'expected': 0.07,
#               'export': 0.03,
#               'forecast': 0.07,
#               'generated': 0.03,
#               'halted': 0.03,
#               'highest': 0.03,
#               'insufficient': 0.03,
#               'limited': 0.03,
#               'longer': 0.03,
#               'negative': 0.03,
#               'now': 0.03,
#               'revised': 0.03,
#               'slowing': 0.03,
#               'smaller': 0.03,
#               'stagnating': 0.05,
#               'steady': 0.03,
#               'the': 0.05,
#               'thus': 0.03,
#               'too': 0.03,
#               'uncertain': 0.03,
#               'weak': 0.03}),
#  ('was',
#   'smaller'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'than': 1.0}),
#  ('smaller',
#   'than'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'a': 0.08,
#               'expected': 0.33,
#               'imports': 0.08,
#               'it': 0.08,
#               'last': 0.17,
#               'normal': 0.08,
#               'previously': 0.08,
#               'usual': 0.08}),
#  ('than',
#   'expected'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'1': 0.01,
#               'according': 0.01,
#               'adjusted': 0.01,
#               'after': 0.01,
#               'and': 0.05,
#               'at': 0.01,
#               'bank': 0.01,
#               'because': 0.03,
#               'borrowing': 0.01,
#               'brazilian': 0.01,
#               'business': 0.01,
#               'consumer': 0.01,
#               'currency': 0.01,
#               'decline': 0.01,
#               'despite': 0.01,
#               'due': 0.04,
#               'economic': 0.04,
#               'economists': 0.01,
#               'fcoj': 0.01,
#               'figures': 0.01,
#               'finance': 0.01,
#               'first': 0.01,
#               'forecast': 0.01,
#               'fourth': 0.01,
#               'gains': 0.01,
#               'growth': 0.04,
#               'improvement': 0.01,
#               'in': 0.01,
#               'increase': 0.01,
#               'japan': 0.01,
#               'just': 0.01,
#               'levels': 0.01,
#               'loan': 0.01,
#               'losses': 0.01,
#               'm0': 0.01,
#               'net': 0.01,
#               'news': 0.03,
#               'number': 0.01,
#               'opening': 0.01,
#               'operating': 0.01,
#               'over': 0.01,
#               'pace': 0.01,
#               'prices': 0.01,
#               'profits': 0.01,
#               'rate': 0.01,
#               'regulatory': 0.01,
#               'removal': 0.01,
#               'results': 0.01,
#               'rise': 0.01,
#               'sales': 0.03,
#               'so': 0.01,
#               'some': 0.01,
#               'spending': 0.01,
#               'the': 0.06,
#               'this': 0.03,
#               'to': 0.01,
#               'u': 0.04,
#               'we': 0.01,
#               'while': 0.01}),
#  ('expected',
#   'due'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'mainly': 0.25,
#               'to': 0.75}),
#  ('lower',
#   'earnings'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'control': 0.11,
#               'expectations': 0.11,
#               'for': 0.22,
#               'from': 0.11,
#               'in': 0.33,
#               'to': 0.11}),
#  ...}

# %%
snew[0:500]
# Out:
# "ASIAN EXPORTERS FEAR DAMAGE FROM U . S .- JAPAN RIFT Mounting trade friction between the U . S . And Japan has raised fears among many of Asia ' s exporting nations that the row could inflict far - reaching economic damage , businessmen and officials said .They told Reuter correspondents in Asian capitals a U . S . Move against Japan might boost protectionist sentiment in the U . S . And lead to curbs on American imports of their products .But some exporters said that while the conflict would hu"
